# %% [markdown]
# <a href="https://colab.research.google.com/github/mavischan01/medill_advanced_data_journalism/blob/main/ILMMAIenrollment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install tabula-py
# %pip install JPype1
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 90.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.6/496.6 kB 7.7 MB/s eta 0:00:00
# ...

# %%
import tabula
import pandas

# %%
url = 'https://hfs.illinois.gov/content/dam/soi/en/web/hfs/sitecollectiondocuments/202507mcoaer.pdf'
tables = tabula.read_pdf(url)
print(type(tables))
print(len(tables))
# Out:
# WARNING:tabula.util:'pages' argument isn't specified.Will extract only from page 1 by default.
# <class 'list'>
# 1

# %%
table = tables[0]
table
# Out:
#     Unnamed: 0    Unnamed: 1  Blue Cross/   Unnamed: 2   Unnamed: 3  \
# 0          NaN  Aetna Better  Blue Shield       Humana     Meridian
# 1       County        Health  of Illinois  Health Plan  Health Plan
# 2        Adams            99           48            9          159
# 3    Alexander            36           16           24            6
# 4         Bond            13            *           16           13
# 5        Boone            83           24           58           47
# 6        Brown             *            *            *           11
# 7       Bureau            83            9           31           37
# 8      Calhoun            14            *            6            6
# 9      Carroll             9            *           16           81
# 10        Cass            16           12           20           24
# 11   Champaign            73           17           53          185
# 12   Christian            31           21           38           30
# ...

# %%
tables = tabula.read_pdf(url, pages = 'all')
print(len(tables))
# Out:
# 8

# %%
tables
# Out:
# [    Unnamed: 0    Unnamed: 1  Blue Cross/   Unnamed: 2   Unnamed: 3  \
#  0          NaN  Aetna Better  Blue Shield       Humana     Meridian
#  1       County        Health  of Illinois  Health Plan  Health Plan
#  2        Adams            99           48            9          159
#  3    Alexander            36           16           24            6
#  4         Bond            13            *           16           13
#  5        Boone            83           24           58           47
#  6        Brown             *            *            *           11
#  7       Bureau            83            9           31           37
#  8      Calhoun            14            *            6            6
#  9      Carroll             9            *           16           81
#  10        Cass            16           12           20           24
#  11   Champaign            73           17           53          185
#  12   Christian            31           21           38           30
# ...
